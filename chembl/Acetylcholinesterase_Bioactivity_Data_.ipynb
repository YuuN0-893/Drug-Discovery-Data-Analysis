# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
protein = new_client.target
query= protein.filter(pref_name__iexact="Acetylcholinesterase")
targets=pd.DataFrame.from_dict(query)
targets
# Out:
#                                      cross_references  \
# 0   [{'xref_id': 'P22303', 'xref_name': None, 'xre...
# 1   [{'xref_id': 'P04058', 'xref_name': None, 'xre...
# 2   [{'xref_id': 'P21836', 'xref_name': None, 'xre...
# 3   [{'xref_id': 'P37136', 'xref_name': None, 'xre...
# 4   [{'xref_id': 'O42275', 'xref_name': None, 'xre...
# 5   [{'xref_id': 'P23795', 'xref_name': None, 'xre...
# 6   [{'xref_id': 'Q95P20', 'xref_name': None, 'xre...
# 7                                                  []
# 8                                                  []
# 9                                                  []
# 10                                                 []
# 11                                                 []
# 12                                                 []
# 13                                                 []
# 14                                                 []
# 15                                                 []
# ...

# %%
s_target= targets.target_chembl_id[0]
s_target
# Out:
# 'CHEMBL220'

# %%
activity= new_client.activity
res= activity.filter(target_chembl_id=s_target).filter(standard_type="IC50")

# %%
df=pd.DataFrame.from_dict(res)

# %%
df.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None        33969                  []
# 1        None             None        37563                  []
# 2        None             None        37565                  []
# 3        None             None        38902                  []
# 4        None             None        41170                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL643384  Inhibitory concentration against acetylcholine...
# 1    CHEMBL643384  Inhibitory concentration against acetylcholine...
# 2    CHEMBL643384  Inhibitory concentration against acetylcholine...
# 3    CHEMBL643384  Inhibitory concentration against acetylcholine...
# 4    CHEMBL643384  Inhibitory concentration against acetylcholine...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# ...

# %%
df.to_csv('acetylcholinesterase_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# Handle missing data from the dataframe

# %%
df2=pd.read_csv("/Users/matteoppa/Documents/Drug-Discovery/Drug-Discovery-Data-Analysis/chembl/acetylcholinesterase_01_bioactivity_data_raw.csv")
df2=df2[df2.standard_value.notna()]
df2=df2[df2.canonical_smiles.notna()]
df2.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0         NaN              NaN        33969                  []
# 1         NaN              NaN        37563                  []
# 2         NaN              NaN        37565                  []
# 3         NaN              NaN        38902                  []
# 4         NaN              NaN        41170                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL643384  Inhibitory concentration against acetylcholine...
# 1    CHEMBL643384  Inhibitory concentration against acetylcholine...
# 2    CHEMBL643384  Inhibitory concentration against acetylcholine...
# 3    CHEMBL643384  Inhibitory concentration against acetylcholine...
# 4    CHEMBL643384  Inhibitory concentration against acetylcholine...
#
#   assay_type  assay_variant_accession  assay_variant_mutation bao_endpoint  \
# 0          B                      NaN                     NaN  BAO_0000190
# ...

# %%
len(df2.canonical_smiles.unique())
# The SMILES format is a linear text format which can describe the connectivity and chirality of a molecule. 
# Canonical SMILES gives a single 'canonical' form for any particular molecule.
# Out:
# 6157

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0         NaN              NaN        33969                  []
# 1         NaN              NaN        37563                  []
# 2         NaN              NaN        37565                  []
# 3         NaN              NaN        38902                  []
# 4         NaN              NaN        41170                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL643384  Inhibitory concentration against acetylcholine...
# 1    CHEMBL643384  Inhibitory concentration against acetylcholine...
# 2    CHEMBL643384  Inhibitory concentration against acetylcholine...
# 3    CHEMBL643384  Inhibitory concentration against acetylcholine...
# 4    CHEMBL643384  Inhibitory concentration against acetylcholine...
#
#   assay_type  assay_variant_accession  assay_variant_mutation bao_endpoint  \
# 0          B                      NaN                     NaN  BAO_0000190
# ...

# %% [markdown]
# Data pre-processing of the bioactivity data.
# Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a
# DataFrame

# %%
cols=["molecule_chembl_id", "canonical_smiles", "standard_value"]
df=df2_nr[cols]
df.head()
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1       CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2       CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3       CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4       CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
#
#    standard_value
# 0           750.0
# 1           100.0
# 2         50000.0
# 3           300.0
# 4           800.0

# %%
#save this new df as our main dataframe to conduct analysis
df.to_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# Labeling compounds as being active, inactive or intermediate
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be active while those greater than 10,000 nM will be considered to be inactive. As for those values in between 1,000 and 10,000 nM will be referred to as intermediate.

# %%
df4 = pd.read_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("INACTIVE")
  elif float(i) <= 1000:
    bioactivity_threshold.append("ACTIVE")
  else:
    bioactivity_threshold.append("INTERMEDIATE")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5.head()
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1       CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2       CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3       CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4       CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
#
#    standard_value     class
# 0           750.0    ACTIVE
# 1           100.0    ACTIVE
# 2         50000.0  INACTIVE
# 3           300.0    ACTIVE
# 4           800.0    ACTIVE

# %%
df5.to_csv('acetylcholinesterase_03_bioactivity_data_clean.csv', index=False)
